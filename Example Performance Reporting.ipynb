# %% [markdown]
# # Imports

# %%
import pandas as pd
from utils.training_utils import *

# %% [markdown]
# ## Load Training Performance Data

# %%
# create a mocked-up dataframe
# replace with your real one, obviously

df = pd.DataFrame({'epoch': {0: 0.0,
  1: 0.0999755859375,
  2: 0.199951171875,
  3: 0.300048828125,
  4: 0.39990234375,
  5: 0.5,
  6: 0.60009765625,
  7: 0.7001953125,
  8: 0.7998046875,
  9: 0.89990234375,
  10: 1.0,
  11: 2.0,
  12: 3.0,
  13: 4.0,
  14: 5.0,
  15: 6.0},
 'f1': {0: 0.659946769352738,
  1: 0.13891310665504214,
  2: 0.6357395056885052,
  3: 0.6337796086508753,
  4: 0.6414591658981452,
  5: 0.5860724233983287,
  6: 0.657983905124947,
  7: 0.6230922362309222,
  8: 0.7192791365481731,
  9: 0.7282151589242054,
  10: 0.7201735357917569,
  11: 0.7736421284808381,
  12: 0.7900990099009901,
  13: 0.7327645385897814,
  14: 0.7768836869056328,
  15: 0.783102721524787},
 'em': {0: 0.49423060726017015,
  1: 0.5008843594710688,
  2: 0.6871894213762317,
  3: 0.7004969257980291,
  4: 0.7052977343552599,
  5: 0.6871051966647014,
  6: 0.7279541817569275,
  7: 0.7129621831045229,
  8: 0.7612229428114209,
  9: 0.7659395266571212,
  10: 0.7609702686768298,
  11: 0.7925545355007159,
  12: 0.8035879727111934,
  13: 0.7704876610797609,
  14: 0.7944917038659143,
  15: 0.8006401078076307}})

# %% [markdown]
# # <font color="Red">Visualizations</font>

# %% [markdown]
# ### <i>Generate Performance Table</i>

# %%
# Generate table output of F1 / EM performance per epoch
kwargs = {'df': df, 
          'title': 'BERT-large Binary Classification on SQuAD v2',
          'cmap': 'BuGn'}

viz_table_scores(**kwargs)
# Out:
# <style  type="text/css" >
#     #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row0_col1 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row0_col2 {
#             background-color:  #f7fcfd;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row1_col1 {
#             background-color:  #1f8742;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row1_col2 {
#             background-color:  #44af79;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row2_col1 {
#             background-color:  #208843;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row2_col2 {
#             background-color:  #39a569;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row3_col1 {
#             background-color:  #1d8640;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row3_col2 {
#             background-color:  #35a063;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row4_col1 {
#             background-color:  #329d5e;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row4_col2 {
#             background-color:  #44af79;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row5_col1 {
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row5_col2 {
#             background-color:  #228a44;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row6_col1 {
#             background-color:  #248c47;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row6_col2 {
#             background-color:  #2f9858;
#             color:  #000000;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row7_col1 {
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row7_col2 {
#             background-color:  #03702e;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row8_col1 {
#             background-color:  #006328;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row8_col2 {
#             background-color:  #006c2c;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row9_col1 {
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row9_col2 {
#             background-color:  #05712f;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row10_col1 {
#             background-color:  #004c1e;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row10_col2 {
#             background-color:  #005020;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row11_col1 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row11_col2 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row12_col1 {
#             background-color:  #006027;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row12_col2 {
#             background-color:  #006729;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row13_col1 {
#             background-color:  #004a1e;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row13_col2 {
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row14_col1 {
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }    #T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row14_col2 {
#             background-color:  #00471c;
#             color:  #f1f1f1;
#         }</style><table id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31" ><caption>BERT-large Binary Classification on SQuAD v2</caption><thead>    <tr>        <th class="col_heading level0 col0" >epoch</th>        <th class="col_heading level0 col1" >f1</th>        <th class="col_heading level0 col2" >em</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row0_col0" class="data row0 col0" >0.1</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row0_col1" class="data row0 col1" >13.891%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row0_col2" class="data row0 col2" >50.088%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row1_col0" class="data row1 col0" >0.2</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row1_col1" class="data row1 col1" >63.574%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row1_col2" class="data row1 col2" >68.719%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row2_col0" class="data row2 col0" >0.3</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row2_col1" class="data row2 col1" >63.378%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row2_col2" class="data row2 col2" >70.050%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row3_col0" class="data row3 col0" >0.4</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row3_col1" class="data row3 col1" >64.146%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row3_col2" class="data row3 col2" >70.530%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row4_col0" class="data row4 col0" >0.5</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row4_col1" class="data row4 col1" >58.607%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row4_col2" class="data row4 col2" >68.711%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row5_col0" class="data row5 col0" >0.6</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row5_col1" class="data row5 col1" >65.798%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row5_col2" class="data row5 col2" >72.795%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row6_col0" class="data row6 col0" >0.7</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row6_col1" class="data row6 col1" >62.309%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row6_col2" class="data row6 col2" >71.296%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row7_col0" class="data row7 col0" >0.8</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row7_col1" class="data row7 col1" >71.928%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row7_col2" class="data row7 col2" >76.122%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row8_col0" class="data row8 col0" >0.9</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row8_col1" class="data row8 col1" >72.822%</td>
#                         <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row8_col2" class="data row8 col2" >76.594%</td>
#             </tr>
#             <tr>
#                                 <td id="T_43ca6f0c_c46c_11ea_a6ff_00d86152fd31row9_col0" class

# %% [markdown]
# ### <i>Generate Performance Plot</i>

# %%
kwargs = {'df': df,
          'xaxis_title': 'Training Epochs',
          'yaxis_title': 'Performance Metric (Dev)',
          'legend_title': 'Metric',
          'title': 'BERT-large Binary Classification Fine-Tuned Performance',
          'subtitle': 'SQuAD v2 (Answer / No Answer Detection)',
          'width': 1920,
          'height': 1080}

viz_bert_performance(**kwargs)
# Out:
# alt.Chart(...)
